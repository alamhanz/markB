# %% [markdown]
# # Data Partitioning
#
# Partitioning data to make it easier to save

# %%
import pandas as pd

# %%
PATH_FILES='../data/instacart-market-basket-analysis/'

# %% [markdown]
# ## Get The Data

# %%
df_prior=pd.read_csv(PATH_FILES+'orders.csv')
# df_prior=pd.read_csv(PATH_FILES+'order_products__prior.csv')

# df_ratings=df_ratings.sort_values('timestamp')
# df_ratings=df_ratings.reset_index()
# del df_ratings['index']

# %%
df_prior.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_prior.shape
# Out:
# (3421083, 7)

# %%
df_prior.shape[0]/3
# Out:
# 1140361.0

# %%
k=1200000
i=9
for i in range(4):
    dk=df_prior[(i*k):(i*k)+k]
    dk.to_csv(PATH_FILES+'orders_'+str(i)+'.csv',index=False)
# df_ratings[(i*k):(i*k)+k]

# %%
len(dk)
# Out:
# 0
